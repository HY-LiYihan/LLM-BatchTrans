# %%
import io
import pandas as pd

try:
    # 尝试使用 gb18030 读取 (兼容 GBK)
    df = pd.read_csv('dataset/raw.csv')
    
    # 提取 '物料描述' 列
    descriptions = df['物料描述']

    print("--- 成功读取 ---")
    print(df['物料描述'][:9]) # 打印前几行检查

except FileNotFoundError:
    print("错误：找不到文件 dataset/raw.csv")
except Exception as e:
    print(f"读取时发生其它错误: {e}")

api_key = open('.apikey', encoding='utf-8').read().strip()

print("--- API Key 已加载 ---")
print(api_key[:5] + "..." + api_key[-5:])  # 打印部分 API Key 以确认加载成功
